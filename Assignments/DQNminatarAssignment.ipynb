# %%
pip install minatar
# Out:
# Collecting minatar
#   Downloading MinAtar-1.0.15-py3-none-any.whl.metadata (685 bytes)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from minatar) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from minatar) (1.4.8)
# Requirement already satisfied: matplotlib>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from minatar) (3.10.0)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.11/dist-packages (from minatar) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from minatar) (2.2.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from minatar) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from minatar) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.11/dist-packages (from minatar) (2025.1)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from minatar) (1.13.1)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from minatar) (0.13.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from minatar) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->minatar) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->minatar) (4.56.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->minatar) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->minatar) (11.1.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->minatar) (2025.1)
# Downloading MinAtar-1.0.15-py3-none-any.whl (16 kB)
# Installing collected packages: minatar
# Successfully installed minatar-1.0.15

# %%
pip install ale-py
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.11/dist-packages (0.10.2)
# Requirement already satisfied: numpy>1.20 in /usr/local/lib/python3.11/dist-packages (from ale-py) (1.26.4)

# %%
pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)

# %%
from time import sleep
import numpy as np
from IPython.display import clear_output
import gymnasium as gym
from gymnasium.envs.registration import register
import torch
from torch import nn

# %%
from gymnasium import spaces
from minatar import Environment

class MinAtarEnv(gym.Env):
    def __init__(self, game_name):
        super().__init__()
        # Initialize the MinAtar environment
        self.minatar_env = Environment(env_name=game_name)

        # Define observation and action spaces
        self.observation_space = spaces.Box(
            low=0,
            high=1,
            shape=self.minatar_env.state_shape(),
            dtype=float
        )
        self.action_space = spaces.Discrete(self.minatar_env.num_actions())

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.minatar_env.reset()
        # Return the initial state and an empty info dict
        return self.minatar_env.state(), {}

    def step(self, action):
        reward, done = self.minatar_env.act(action)
        return self.minatar_env.state(), reward, done, done, {}

    def render(self, mode="human"):
        arr=(self.minatar_env.state()*np.arange(1,7)).max(axis=2)
        num_to_char = {
          0: ' ',
          1: '\u2569',
          2: '\u2ADA',
          3: '\u2ADA',
          4: '\u2ADA',
          5: '|',
          6: ':'
        }
        char_grid = np.vectorize(num_to_char.get)(arr)
        padded_rows = []
        for row in char_grid:
          padded_row = ''.join(char for char in row)
          padded_rows.append(padded_row)
        final_grid = '\n'.join(padded_rows)
        print(final_grid)

    def close(self):
        # Clean up resources if needed
        pass


# Instantiate the custom MinAtar space_invaders environment
env = MinAtarEnv("space_invaders")

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
import matplotlib.pyplot as plt
from collections import deque

class DQN(nn.Module):
    def __init__(self, input_shape, num_actions):
        super(DQN, self).__init__()
        c, h, w = input_shape  # Ensure correct channels
        self.conv1 = nn.Conv2d(c, 32, kernel_size=3, stride=1)  # Change input channels to match env
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(64 * (h - 4) * (w - 4), 128)
        self.fc2 = nn.Linear(128, num_actions)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        return self.fc2(x)

# %%
# Experience Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = zip(*batch)
        return np.array(state), np.array(action), np.array(reward), np.array(next_state), np.array(done)

    def __len__(self):
        return len(self.buffer)

# %%
# Epsilon-greedy policy
class EpsilonGreedyPolicy:
    def __init__(self, start_epsilon, end_epsilon, decay):
        self.epsilon = start_epsilon
        self.end_epsilon = end_epsilon
        self.decay = decay

    def select_action(self, q_network, state, num_actions, device):
        if random.random() < self.epsilon:
            return random.randrange(num_actions)
        else:
            state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            with torch.no_grad():
                return q_network(state).argmax(dim=1).item()

    def decay_epsilon(self):
        self.epsilon = max(self.end_epsilon, self.epsilon * self.decay)

# %%
# Training function
def train_dqn(env, num_episodes=5000, batch_size=32, gamma=0.99, lr=1e-3, buffer_size=10000):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    input_shape = (env.observation_space.shape[2], env.observation_space.shape[0], env.observation_space.shape[1])
    num_actions = env.action_space.n

    print("Environment Observation Space Shape:", env.observation_space.shape)

    q_network = DQN(input_shape, num_actions).to(device)
    target_network = DQN(input_shape, num_actions).to(device)
    target_network.load_state_dict(q_network.state_dict())

    optimizer = optim.Adam(q_network.parameters(), lr=lr)
    replay_buffer = ReplayBuffer(buffer_size)
    policy = EpsilonGreedyPolicy(1.0, 0.1, 0.995)
    rewards_per_episode = []

    for episode in range(num_episodes):
        state, _ = env.reset()
        state = np.moveaxis(state, -1, 0)  # Ensure correct input shape
        print(f"Episode {episode} started. Initial State Shape: {state.shape}")
        done = False
        total_reward = 0
        step = 0

        while not done:
            action = policy.select_action(q_network, state, num_actions, device)
            next_state, reward, done, _, _ = env.step(action)
            next_state = np.moveaxis(next_state, -1, 0)  # Ensure correct input shape
            replay_buffer.push(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            step += 1

            if len(replay_buffer) > batch_size:
                states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)
                states = torch.tensor(states, dtype=torch.float32, device=device)
                actions = torch.tensor(actions, dtype=torch.long, device=device).unsqueeze(1)
                rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
                next_states = torch.tensor(next_states, dtype=torch.float32, device=device)
                dones = torch.tensor(dones, dtype=torch.float32, device=device)

                q_values = q_network(states).gather(1, actions).squeeze(1)
                next_q_values = target_network(next_states).max(1)[0]
                target_q_values = rewards + (gamma * next_q_values * (1 - dones))

                loss = nn.MSELoss()(q_values, target_q_values.detach())
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        rewards_per_episode.append(total_reward)
        policy.decay_epsilon()

        if episode % 10 == 0:
            target_network.load_state_dict(q_network.state_dict())
            print(f"Episode {episode}: Total Reward: {total_reward}, Epsilon: {policy.epsilon:.2f}")

    # Plot learning curve
    plt.plot(range(num_episodes), rewards_per_episode)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("DQN Learning Curve")
    plt.show()

    return q_network

# %%
env = MinAtarEnv("space_invaders")  # Assuming you have defined this earlier
trained_model = train_dqn(env, num_episodes=5000)
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 209 started. Initial State Shape: (6, 10, 10)
# Episode 210 started. Initial State Shape: (6, 10, 10)
# Episode 210: Total Reward: 4, Epsilon: 0.35
# Episode 211 started. Initial State Shape: (6, 10, 10)
# Episode 212 started. Initial State Shape: (6, 10, 10)
# Episode 213 started. Initial State Shape: (6, 10, 10)
# Episode 214 started. Initial State Shape: (6, 10, 10)
# Episode 215 started. Initial State Shape: (6, 10, 10)
# Episode 216 started. Initial State Shape: (6, 10, 10)
# Episode 217 started. Initial State Shape: (6, 10, 10)
# Episode 218 started. Initial State Shape: (6, 10, 10)
# Episode 219 started. Initial State Shape: (6, 10, 10)
# Episode 220 started. Initial State Shape: (6, 10, 10)
# Episode 220: Total Reward: 18, Epsilon: 0.33
# Episode 221 started. Initial State Shape: (6, 10, 10)
# Episode 222 started. Initial State Shape: (6, 10, 10)
# Episode 223 started. Initial State Shape: (6, 10, 10)
# Episode 224 started. Initial State Shape: (6, 10, 10)
# Episode 225 started. Initial State Shape: (6, 10, 10)
# Episode 226 started. Initial State Shape: (6, 10, 10)
# Episode 227 started. Initial State Shape: (6, 10, 10)
# Episode 228 started. Initial State Shape: (6, 10, 10)
# Episode 229 started. Initial State Shape: (6, 10, 10)
# Episode 230 started. Initial State Shape: (6, 10, 10)
# Episode 230: Total Reward: 16, Epsilon: 0.31
# Episode 231 started. Initial State Shape: (6, 10, 10)
# Episode 232 started. Initial State Shape: (6, 10, 10)
# Episode 233 started. Initial State Shape: (6, 10, 10)
# Episode 234 started. Initial State Shape: (6, 10, 10)
# Episode 235 started. Initial State Shape: (6, 10, 10)
# Episode 236 started. Initial State Shape: (6, 10, 10)
# Episode 237 started. Initial State Shape: (6, 10, 10)
# Episode 238 started. Initial State Shape: (6, 10, 10)
# Episode 239 started. Initial State Shape: (6, 10, 10)
# Episode 240 started. Initial State Shape: (6, 10, 10)
# Episode 240: Total Reward: 21, Epsilon: 0.30
# Episode 241 started. Initial State Shape: (6, 10, 10)
# Episode 242 started. Initial State Shape: (6, 10, 10)
# Episode 243 started. Initial State Shape: (6, 10, 10)
# Episode 244 started. Initial State Shape: (6, 10, 10)
# Episode 245 started. Initial State Shape: (6, 10, 10)
# Episode 246 started. Initial State Shape: (6, 10, 10)
# Episode 247 started. Initial State Shape: (6, 10, 10)
# Episode 248 started. Initial State Shape: (6, 10, 10)
# Episode 249 started. Initial State Shape: (6, 10, 10)
# Episode 250 started. Initial State Shape: (6, 10, 10)
# Episode 250: Total Reward: 4, Epsilon: 0.28
# Episode 251 started. Initial State Shape: (6, 10, 10)
# Episode 252 started. Initial State Shape: (6, 10, 10)
# Episode 253 started. Initial State Shape: (6, 10, 10)
# Episode 254 started. Initial State Shape: (6, 10, 10)
# Episode 255 started. Initial State Shape: (6, 10, 10)
# Episode 256 started. Initial State Shape: (6, 10, 10)
# Episode 257 started. Initial State Shape: (6, 10, 10)
# Episode 258 started. Initial State Shape: (6, 10, 10)
# Episode 259 started. Initial State Shape: (6, 10, 10)
# Episode 260 started. Initial State Shape: (6, 10, 10)
# Episode 260: Total Reward: 16, Epsilon: 0.27
# Episode 261 started. Initial State Shape: (6, 10, 10)
# Episode 262 started. Initial State Shape: (6, 10, 10)
# Episode 263 started. Initial State Shape: (6, 10, 10)
# Episode 264 started. Initial State Shape: (6, 10, 10)
# Episode 265 started. Initial State Shape: (6, 10, 10)
# Episode 266 started. Initial State Shape: (6, 10, 10)
# Episode 267 started. Initial State Shape: (6, 10, 10)
# Episode 268 started. Initial State Shape: (6, 10, 10)
# Episode 269 started. Initial State Shape: (6, 10, 10)
# Episode 270 started. Initial State Shape: (6, 10, 10)
# Episode 270: Total Reward: 9, Epsilon: 0.26
# Episode 271 started. Initial State Shape: (6, 10, 10)
# Episode 272 started. Initial State Shape: (6, 10, 10)
# Episode 273 started. Initial State Shape: (6, 10, 10)
# Episode 274 started. Initial State Shape: (6, 10, 10)
# Episode 275 started. Initial State Shape: (6, 10, 10)
# Episode 276 started. Initial State Shape: (6, 10, 10)
# Episode 277 started. Initial State Shape: (6, 10, 10)
# Episode 278 started. Initial State Shape: (6, 10, 10)
# Episode 279 started. Initial State Shape: (6, 10, 10)
# Episode 280 started. Initial State Shape: (6, 10, 10)
# Episode 280: Total Reward: 23, Epsilon: 0.24
# Episode 281 started. Initial State Shape: (6, 10, 10)
# Episode 282 started. Initial State Shape: (6, 10, 10)
# Episode 283 started. Initial State Shape: (6, 10, 10)
# Episode 284 started. Initial State Shape: (6, 10, 10)
# Episode 285 started. Initial State Shape: (6, 10, 10)
# Episode 286 started. Initial State Shape: (6, 10, 10)
# Episode 287 started. Initial State Shape: (6, 10, 10)
# Episode 288 started. Initial State Shape: (6, 10, 10)
# Episode 289 started. Initial State Shape: (6, 10, 10)
# Episode 290 started. Initial State Shape: (6, 10, 10)
# Episode 290: Total Reward: 6, Epsilon: 0.23
# Episode 291 started. Initial State Shape: (6, 10, 10)
# Episode 292 started. Initial State Shape: (6, 10, 10)
# Episode 293 started. Initial State Shape: (6, 10, 10)
# Episode 294 started. Initial State Shape: (6, 10, 10)
# Episode 295 started. Initial State Shape: (6, 10, 10)
# Episode 296 started. Initial State Shape: (6, 10, 10)
# Episode 297 started. Initial State Shape: (6, 10, 10)
# Episode 298 started. Initial State Shape: (6, 10, 10)
# Episode 299 started. Initial State Shape: (6, 10, 10)
# Episode 300 started. Initial State Shape: (6, 10, 10)
# Episode 300: Total Reward: 22, Epsilon: 0.22
# Episode 301 started. Initial State Shape: (6, 10, 10)
# Episode 302 started. Initial State Shape: (6, 10, 10)
# Episode 303 started. Initial State Shape: (6, 10, 10)
# Episode 304 started. Initial State Shape: (6, 10, 10)
# Episode 305 started. Initial State Shape: (6, 10, 10)
# Episode 306 started. Initial State Shape: (6, 10, 10)
# Episode 307 started. Initial State Shape: (6, 10, 10)
# Episode 308 started. Initial State Shape: (6, 10, 10)
# Episode 309 started. Initial State Shape: (6, 10, 10)
# Episode 310 started. Initial State Shape: (6, 10, 10)
# Episode 310: Total Reward: 3, Epsilon: 0.21
# Episode 311 started. Initial State Shape: (6, 10, 10)
# Episode 312 started. Initial State Shape: (6, 10, 10)
# Episode 313 started. Initial State Shape: (6, 10, 10)
# Episode 314 started. Initial State Shape: (6, 10, 10)
# Episode 315 started. Initial State Shape: (6, 10, 10)
# Episode 316 started. Initial State Shape: (6, 10, 10)
# Episode 317 started. Initial State Shape: (6, 10, 10)
# Episode 318 started. Initial State Shape: (6, 10, 10)
# Episode 319 started. Initial State Shape: (6, 10, 10)
# Episode 320 started. Initial State Shape: (6, 10, 10)
# Episode 320: Total Reward: 19, Epsilon: 0.20
# Episode 321 started. Initial State Shape: (6, 10, 10)
# Episode 322 started. Initial State Shape: (6, 10, 10)
# Episode 323 started. Initial State Shape: (6, 10, 10)
# Episode 324 started. Initial State Shape: (6, 10, 10)
# Episode 325 started. Initial State Shape: (6, 10, 10)
# Episode 326 started. Initial State Shape: (6, 10, 10)
# Episode 327 started. Initial State Shape: (6, 10, 10)
# Episode 328 started. Initial State Shape: (6, 10, 10)
# Episode 329 started. Initial State Shape: (6, 10, 10)
# Episode 330 started. Initial State Shape: (6, 10, 10)
# Episode 330: Total Reward: 19, Epsilon: 0.19
# Episode 331 started. Initial State Shape: (6, 10, 10)
# Episode 332 started. Initial State Shape: (6, 10, 10)
# Episode 333 started. Initial State Shape: (6, 10, 10)
# Episode 334 started. Initial State Shape: (6, 10, 10)
# Episode 335 started. Initial State Shape: (6, 10, 10)
# Episode 336 started. Initial State Shape: (6, 10, 10)
# Episode 337 started. Initial State Shape: (6, 10, 10)
# Episode 338 started. Initial State Shape: (6, 10, 10)
# Episode 339 started. Initial State Shape: (6, 10, 10)
# Episode 340 started. Initial State Shape: (6, 10, 10)
# Episode 340: Total Reward: 6, Epsilon: 0.18
# Episode 341 started. Initial State Shape: (6, 10, 10)
# Episode 342 started. Initial State Shape: (6, 10, 10)
# Episode 343 started. Initial State Shape: (6, 10, 10)
# Episode 344 started. Initial State Shape: (6, 10, 10)
# Episode 345 started. Initial State Shape: (6, 10, 10)
# Episode 346 started. Initial State Shape: (6, 10, 10)
# Episode 347 started. Initial State Shape: (6, 10, 10)
# Episode 348 started. Initial State Shape: (6, 10, 10)
# Episode 349 started. Initial State Shape: (6, 10, 10)
# Episode 350 started. Initial State Shape: (6, 10, 10)
# Episode 350: Total Reward: 20, Epsilon: 0.17
# Episode 351 started. Initial State Shape: (6, 10, 10)
# Episode 352 started. Initial State Shape: (6, 10, 10)
# Episode 353 started. Initial State Shape: (6, 10, 10)
# Episode 354 started. Initial State Shape: (6, 10, 10)
# Episode 355 started. Initial State Shape: (6, 10, 10)
# Episode 356 started. Initial State Shape: (6, 10, 10)
# Episode 357 started. Initial State Shape: (6, 10, 10)
# Episode 358 started. Initial State Shape: (6, 10, 10)
# Episode 359 started. Initial State Shape: (6, 10, 10)
# Episode 360 started. Initial State Shape: (6, 10, 10)
# Episode 360: Total Reward: 3, Epsilon: 0.16
# Episode 361 started. Initial State Shape: (6, 10, 10)
# Episode 362 started. Initial State Shape: (6, 10, 10)
# Episode 363 started. Initial State Shape: (6, 10, 10)
# Episode 364 started. Initial State Shape: (6, 10, 10)
# Episode 365 started. Initial State Shape: (6, 10, 10)
# Episode 366 started. Initial State Shape: (6, 10, 10)
# Episode 367 started. Initial State Shape: (6, 10, 10)
# Episode 368 started. Initial State Shape: (6, 10, 10)
# Episode 369 started. Initial State Shape: (6, 10, 10)
# Episode 370 started. Initial State Shape: (6, 10, 10)
# Episode 370: Total Reward: 10, Epsilon: 0.16
# Episode 371 started. Initial State Shape: (6, 10, 10)
# Episode 372 started. Initial State Shape: (6, 10, 10)
# Episode 373 started. Initial State Shape: (6, 10, 10)
# Episode 374 started. Initial State Shape: (6, 10, 10)
# Episode 375 started. Initial State Shape: (6, 10, 10)
# Episode 376 started. Initial State Shape: (6, 10, 10)
# Episode 377 started. Initial State Shape: (6, 10, 10)
# Episode 378 started. Initial State Shape: (6, 10, 10)
# Episode 379 started. Initial State Shape: (6, 10, 10)
# Episode 380 started. Initial State Shape: (6, 10, 10)
# Episode 380: Total Reward: 20, Epsilon: 0.15
# Episode 381 started. Initial State Shape: (6, 10, 10)
# Episode 382 started. Initial State Shape: (6, 10, 10)
# Episode 383 started. Initial State Shape: (6, 10, 10)
# Episode 384 started. Initial State Shape: (6, 10, 10)
# Episode 385 started. Initial State Shape: (6, 10, 10)
# Episode 386 started. Initial State Shape: (6, 10, 10)
# Episode 387 started. Initial State Shape: (6, 10, 10)
# Episode 388 started. Initial State Shape: (6, 10, 10)
# Episode 389 started. Initial State Shape: (6, 10, 10)
# Episode 390 started. Initial State Shape: (6, 10, 10)
# Episode 390: Total Reward: 21, Epsilon: 0.14
# Episode 391 started. Initial State Shape: (6, 10, 10)
# Episode 392 started. Initial State Shape: (6, 10, 10)
# Episode 393 started. Initial State Shape: (6, 10, 10)
# Episode 394 started. Initial State Shape: (6, 10, 10)
# Episode 395 started. Initial State Shape: (6, 10, 10)
# Episode 396 started. Initial State Shape: (6, 10, 10)
# Episode 397 started. Initial State Shape: (6, 10, 10)
# Episode 398 started. Initial State Shape: (6, 10, 10)
# Episode 399 started. Initial State Shape: (6, 10, 10)
# Episode 400 started. Initial State Shape: (6, 10, 10)
# Episode 400: Total Reward: 13, Epsilon: 0.13
# Episode 401 started. Initial State Shape: (6, 10, 10)
# Episode 402 started. Initial State Shape: (6, 10, 10)
# Episode 403 started. Initial State Shape: (6, 10, 10)
# Episode 404 started. Initial State Shape: (6, 10, 10)
# Episode 405 started. Initial State Shape: (6, 10, 10)
# Episode 406 started. Initial State Shape: (6, 10, 10)
# Episode 407 started. Initial State Shape: (6, 10, 10)
# Episode 408 started. Initial State Shape: (6, 10, 10)
# Episode 409 started. Initial State Shape: (6, 10, 10)
# Episode 410 started. Initial State Shape: (6, 10, 10)
# Episode 410: Total Reward: 23, Epsilon: 0.13
# Episode 411 started. Initial State Shape: (6, 10, 10)
# Episode 412 started. Initial State Shape: (6, 10, 10)
# Episode 413 started. Initial State Shape: (6, 10, 10)
# Episode 414 started. Initial State Shape: (6, 10, 10)
# Episode 415 started. Initial State Shape: (6, 10, 10)
# Episode 416 started. Initial State Shape: (6, 10, 10)
# Episode 417 started. Initial State Shape: (6, 10, 10)
# Episode 418 started. Initial State Shape: (6, 10, 10)
# Episode 419 started. Initial State Shape: (6, 10, 10)
# Episode 420 started. Initial State Shape: (6, 10, 10)
# Episode 420: Total Reward: 21, Epsilon: 0.12
# Episode 421 started. Initial State Shape: (6, 10, 10)
# Episode 422 started. Initial State Shape: (6, 10, 10)
# Episode 423 started. Initial State Shape: (6, 10, 10)
# Episode 424 started. Initial State Shape: (6, 10, 10)
# Episode 425 started. Initial State Shape: (6, 10, 10)
# Episode 426 started. Initial State Shape: (6, 10, 10)
# Episode 427 started. Initial State Shape: (6, 10, 10)
# Episode 428 started. Initial State Shape: (6, 10, 10)
# Episode 429 started. Initial State Shape: (6, 10, 10)
# Episode 430 started. Initial State Shape: (6, 10, 10)
# Episode 430: Total Reward: 23, Epsilon: 0.12
# Episode 431 started. Initial State Shape: (6, 10, 10)
# Episode 432 started. Initial State Shape: (6, 10, 10)
# Episode 433 started. Initial State Shape: (6, 10, 10)
# Episode 434 started. Initial State Shape: (6, 10, 10)
# Episode 435 started. Initial State Shape: (6, 10, 10)
# Episode 436 started. Initial State Shape: (6, 10, 10)
# Episode 437 started. Initial State Shape: (6, 10, 10)
# Episode 438 started. Initial State Shape: (6, 10, 10)
# Episode 439 started. Initial State Shape: (6, 10, 10)
# Episode 440 started. Initial State Shape: (6, 10, 10)
# Episode 440: Total Reward: 20, Epsilon: 0.11
# Episode 441 started. Initial State Shape: (6, 10, 10)
# Episode 442 started. Initial State Shape: (6, 10, 10)
# Episode 443 started. Initial State Shape: (6, 10, 10)
# Episode 444 started. Initial State Shape: (6, 10, 10)
# Episode 445 started. Initial State Shape: (6, 10, 10)
# Episode 446 started. Initial State Shape: (6, 10, 10)
# Episode 447 started. Initial State Shape: (6, 10, 10)
# Episode 448 started. Initial State Shape: (6, 10, 10)
# Episode 449 started. Initial State Shape: (6, 10, 10)
# Episode 450 started. Initial State Shape: (6, 10, 10)
# Episode 450: Total Reward: 22, Epsilon: 0.10
# Episode 451 started. Initial State Shape: (6, 10, 10)
# Episode 452 started. Initial State Shape: (6, 10, 10)
# Episode 453 started. Initial State Shape: (6, 10, 10)
# Episode 454 started. Initial State Shape: (6, 10, 10)
# Episode 455 started. Initial State Shape: (6, 10, 10)
# Episode 456 started. Initial State Shape: (6, 10, 10)
# Episode 457 started. Initial State Shape: (6, 10, 10)
# Episode 458 started. Initial State Shape: (6, 10, 10)
# Episode 459 started. Initial State Shape: (6, 10, 10)
# Episode 460 started. Initial State Shape: (6, 10, 10)
# Episode 460: Total Reward: 21, Epsilon: 0.10
# Episode 461 started. Initial State Shape: (6, 10, 10)
# Episode 462 started. Initial State Shape: (6, 10, 10)
# Episode 463 started. Initial State Shape: (6, 10, 10)
# Episode 464 started. Initial State Shape: (6, 10, 10)
# Episode 465 started. Initial State Shape: (6, 10, 10)
# Episode 466 started. Initial State Shape: (6, 10, 10)
# Episode 467 started. Initial State Shape: (6, 10, 10)
# Episode 468 started. Initial State Shape: (6, 10, 10)
# Episode 469 started. Initial State Shape: (6, 10, 10)
# Episode 470 started. Initial State Shape: (6, 10, 10)
# Episode 470: Total Reward: 20, Epsilon: 0.10
# Episode 471 started. Initial State Shape: (6, 10, 10)
# Episode 472 started. Initial State Shape: (6, 10, 10)
# Episode 473 started. Initial State Shape: (6, 10, 10)
# Episode 474 started. Initial State Shape: (6, 10, 10)
# Episode 475 started. Initial State Shape: (6, 10, 10)
# Episode 476 started. Initial State Shape: (6, 10, 10)
# Episode 477 started. Initial State Shape: (6, 10, 10)
# Episode 478 started. Initial State Shape: (6, 10, 10)
# Episode 479 started. Initial State Shape: (6, 10, 10)
# Episode 480 started. Initial State Shape: (6, 10, 10)
# Episode 480: Total Reward: 3, Epsilon: 0.10
# Episode 481 started. Initial State Shape: (6, 10, 10)
# Episode 482 started. Initial State Shape: (6, 10, 10)
# Episode 483 started. Initial State Shape: (6, 10, 10)
# Episode 484 started. Initial State Shape: (6, 10, 10)
# Episode 485 started. Initial State Shape: (6, 10, 10)
# Episode 486 started. Initial State Shape: (6, 10, 10)
# Episode 487 started. Initial State Shape: (6, 10, 10)
# Episode 488 started. Initial State Shape: (6, 10, 10)
# Episode 489 started. Initial State Shape: (6, 10, 10)
# Episode 490 started. Initial State Shape: (6, 10, 10)
# Episode 490: Total Reward: 19, Epsilon: 0.10
# Episode 491 started. Initial State Shape: (6, 10, 10)
# Episode 492 started. Initial State Shape: (6, 10, 10)
# Episode 493 started. Initial State Shape: (6, 10, 10)
# Episode 494 started. Initial State Shape: (6, 10, 10)
# Episode 495 started. Initial State Shape: (6, 10, 10)
# Episode 496 started. Initial State Shape: (6, 10, 10)
# Episode 497 started. Initial State Shape: (6, 10, 10)
# Episode 498 started. Initial State Shape: (6, 10, 10)
# Episode 499 started. Initial State Shape: (6, 10, 10)
# Episode 500 started. Initial State Shape: (6, 10, 10)
# Episode 500: Total Reward: 3, Epsilon: 0.10
# Episode 501 started. Initial State Shape: (6, 10, 10)
# Episode 502 started. Initial State Shape: (6, 10, 10)
# Episode 503 started. Initial State Shape: (6, 10, 10)
# Episode 504 started. Initial State Shape: (6, 10, 10)
# Episode 505 started. Initial State Shape: (6, 10, 10)
# Episode 506 started. Initial State Shape: (6, 10, 10)
# Episode 507 started. Initial State Shape: (6, 10, 10)
# Episode 508 started. Initial State Shape: (6, 10, 10)
# Episode 509 started. Initial State Shape: (6, 10, 10)
# Episode 510 started. Initial State Shape: (6, 10, 10)
# Episode 510: Total Reward: 23, Epsilon: 0.10
# Episode 511 started. Initial State Shape: (6, 10, 10)
# Episode 512 started. Initial State Shape: (6, 10, 10)
# Episode 513 started. Initial State Shape: (6, 10, 10)
# Episode 514 started. Initial State Shape: (6, 10, 10)
# Episode 515 started. Initial State Shape: (6, 10, 10)
# Episode 516 started. Initial State Shape: (6, 10, 10)
# Episode 517 started. Initial State Shape: (6, 10, 10)
# Episode 518 started. Initial State Shape: (6, 10, 10)
# Episode 519 started. Initial State Shape: (6, 10, 10)
# Episode 520 started. Initial State Shape: (6, 10, 10)
# Episode 520: Total Reward: 30, Epsilon: 0.10
# Episode 521 started. Initial State Shape: (6, 10, 10)
# Episode 522 started. Initial State Shape: (6, 10, 10)
# Episode 523 started. Initial State Shape: (6, 10, 10)
# Episode 524 started. Initial State Shape: (6, 10, 10)
# Episode 525 started. Initial State Shape: (6, 10, 10)
# Episode 526 started. Initial State Shape: (6, 10, 10)
# Episode 527 started. Initial State Shape: (6, 10, 10)
# Episode 528 started. Initial State Shape: (6, 10, 10)
# Episode 529 started. Initial State Shape: (6, 10, 10)
# Episode 530 started. Initial State Shape: (6, 10, 10)
# Episode 530: Total Reward: 21, Epsilon: 0.10
# Episode 531 started. Initial State Shape: (6, 10, 10)
# Episode 532 started. Initial State Shape: (6, 10, 10)
# Episode 533 started. Initial State Shape: (6, 10, 10)
# Episode 534 started. Initial State Shape: (6, 10, 10)
# Episode 535 started. Initial State Shape: (6, 10, 10)
# Episode 536 started. Initial State Shape: (6, 10, 10)
# Episode 537 started. Initial State Shape: (6, 10, 10)
# Episode 538 started. Initial State Shape: (6, 10, 10)
# Episode 539 started. Initial State Shape: (6, 10, 10)
# Episode 540 started. Initial State Shape: (6, 10, 10)
# Episode 540: Total Reward: 23, Epsilon: 0.10
# Episode 541 started. Initial State Shape: (6, 10, 10)
# Episode 542 started. Initial State Shape: (6, 10, 10)
# Episode 543 started. Initial State Shape: (6, 10, 10)
# Episode 544 started. Initial State Shape: (6, 10, 10)
# Episode 545 started. Initial State Shape: (6, 10, 10)
# Episode 546 started. Initial State Shape: (6, 10, 10)
# Episode 547 started. Initial State Shape: (6, 10, 10)
# Episode 548 started. Initial State Shape: (6, 10, 10)
# Episode 549 started. Initial State Shape: (6, 10, 10)
# Episode 550 started. Initial State Shape: (6, 10, 10)
# Episode 550: Total Reward: 23, Epsilon: 0.10
# Episode 551 started. Initial State Shape: (6, 10, 10)
# Episode 552 started. Initial State Shape: (6, 10, 10)
# Episode 553 started. Initial State Shape: (6, 10, 10)
# Episode 554 started. Initial State Shape: (6, 10, 10)
# Episode 555 started. Initial State Shape: (6, 10, 10)
# Episode 556 started. Initial State Shape: (6, 10, 10)
# Episode 557 started. Initial State Shape: (6, 10, 10)
# Episode 558 started. Initial State Shape: (6, 10, 10)
# Episode 559 started. Initial State Shape: (6, 10, 10)
# Episode 560 started. Initial State Shape: (6, 10, 10)
# Episode 560: Total Reward: 20, Epsilon: 0.10
# Episode 561 started. Initial State Shape: (6, 10, 10)
# Episode 562 started. Initial State Shape: (6, 10, 10)
# Episode 563 started. Initial State Shape: (6, 10, 10)
# Episode 564 started. Initial State Shape: (6, 10, 10)
# Episode 565 started. Initial State Shape: (6, 10, 10)
# Episode 566 started. Initial State Shape: (6, 10, 10)
# Episode 567 started. Initial State Shape: (6, 10, 10)
# Episode 568 started. Initial State Shape: (6, 10, 10)
# Episode 569 started. Initial State Shape: (6, 10, 10)
# Episode 570 started. Initial State Shape: (6, 10, 10)
# Episode 570: Total Reward: 23, Epsilon: 0.10
# Episode 571 started. Initial State Shape: (6, 10, 10)
# Episode 572 started. Initial State Shape: (6, 10, 10)
# Episode 573 started. Initial State Shape: (6, 10, 10)
# Episode 574 started. Initial State Shape: (6, 10, 10)
# Episode 575 started. Initial State Shape: (6, 10, 10)
# Episode 576 started. Initial State Shape: (6, 10, 10)
# Episode 577 started. Initial State Shape: (6, 10, 10)
# Episode 578 started. Initial State Shape: (6, 10, 10)
# Episode 579 started. Initial State Shape: (6, 10, 10)
# Episode 580 started. Initial State Shape: (6, 10, 10)
# Episode 580: Total Reward: 22, Epsilon: 0.10
# Episode 581 started. Initial State Shape: (6, 10, 10)
# Episode 582 started. Initial State Shape: (6, 10, 10)
# Episode 583 started. Initial State Shape: (6, 10, 10)
# Episode 584 started. Initial State Shape: (6, 10, 10)
# Episode 585 started. Initial State Shape: (6, 10, 10)
# Episode 586 started. Initial State Shape: (6, 10, 10)
# Episode 587 started. Initial State Shape: (6, 10, 10)
# Episode 588 started. Initial State Shape: (6, 10, 10)
# Episode 589 started. Initial State Shape: (6, 10, 10)
# Episode 590 started. Initial State Shape: (6, 10, 10)
# Episode 590: Total Reward: 19, Epsilon: 0.10
# Episode 591 started. Initial State Shape: (6, 10, 10)
# Episode 592 started. Initial State Shape: (6, 10, 10)
# Episode 593 started. Initial State Shape: (6, 10, 10)
# Episode 594 started. Initial State Shape: (6, 10, 10)
# Episode 595 started. Initial State Shape: (6, 10, 10)
# Episode 596 started. Initial State Shape: (6, 10, 10)
# Episode 597 started. Initial State Shape: (6, 10, 10)
# Episode 598 started. Initial State Shape: (6, 10, 10)
# Episode 599 started. Initial State Shape: (6, 10, 10)
# Episode 600 started. Initial State Shape: (6, 10, 10)
# Episode 600: Total Reward: 44, Epsilon: 0.10
# Episode 601 started. Initial State Shape: (6, 10, 10)
# Episode 602 started. Initial State Shape: (6, 10, 10)
# Episode 603 started. Initial State Shape: (6, 10, 10)
# Episode 604 started. Initial State Shape: (6, 10, 10)
# Episode 605 started. Initial State Shape: (6, 10, 10)
# Episode 606 started. Initial State Shape: (6, 10, 10)
# Episode 607 started. Initial State Shape: (6, 10, 10)
# Episode 608 started. Initial State Shape: (6, 10, 10)
# Episode 609 started. Initial State Shape: (6, 10, 10)
# Episode 610 started. Initial State Shape: (6, 10, 10)
# Episode 610: Total Reward: 11, Epsilon: 0.10
# Episode 611 started. Initial State Shape: (6, 10, 10)
# Episode 612 started. Initial State Shape: (6, 10, 10)
# Episode 613 started. Initial State Shape: (6, 10, 10)
# Episode 614 started. Initial State Shape: (6, 10, 10)
# Episode 615 started. Initial State Shape: (6, 10, 10)
# Episode 616 started. Initial State Shape: (6, 10, 10)
# Episode 617 started. Initial State Shape: (6, 10, 10)
# Episode 618 started. Initial State Shape: (6, 10, 10)
# Episode 619 started. Initial State Shape: (6, 10, 10)
# Episode 620 started. Initial State Shape: (6, 10, 10)
# Episode 620: Total Reward: 23, Epsilon: 0.10
# Episode 621 started. Initial State Shape: (6, 10, 10)
# Episode 622 started. Initial State Shape: (6, 10, 10)
# Episode 623 started. Initial State Shape: (6, 10, 10)
# Episode 624 started. Initial State Shape: (6, 10, 10)
# Episode 625 started. Initial State Shape: (6, 10, 10)
# Episode 626 started. Initial State Shape: (6, 10, 10)
# Episode 627 started. Initial State Shape: (6, 10, 10)
# Episode 628 started. Initial State Shape: (6, 10, 10)
# Episode 629 started. Initial State Shape: (6, 10, 10)
# Episode 630 started. Initial State Shape: (6, 10, 10)
# Episode 630: Total Reward: 4, Epsilon: 0.10
# Episode 631 started. Initial State Shape: (6, 10, 10)
# Episode 632 started. Initial State Shape: (6, 10, 10)
# Episode 633 started. Initial State Shape: (6, 10, 10)
# Episode 634 started. Initial State Shape: (6, 10, 10)
# Episode 635 started. Initial State Shape: (6, 10, 10)
# Episode 636 started. Initial State Shape: (6, 10, 10)
# Episode 637 started. Initial State Shape: (6, 10, 10)
# Episode 638 started. Initial State Shape: (6, 10, 10)
# Episode 639 started. Initial State Shape: (6, 10, 10)
# Episode 640 started. Initial State Shape: (6, 10, 10)
# Episode 640: Total Reward: 14, Epsilon: 0.10
# Episode 641 started. Initial State Shape: (6, 10, 10)
# Episode 642 started. Initial State Shape: (6, 10, 10)
# Episode 643 started. Initial State Shape: (6, 10, 10)
# Episode 644 started. Initial State Shape: (6, 10, 10)
# Episode 645 started. Initial State Shape: (6, 10, 10)
# Episode 646 started. Initial State Shape: (6, 10, 10)
# Episode 647 started. Initial State Shape: (6, 10, 10)
# Episode 648 started. Initial State Shape: (6, 10, 10)
# Episode 649 started. Initial State Shape: (6, 10, 10)
# Episode 650 started. Initial State Shape: (6, 10, 10)
# Episode 650: Total Reward: 16, Epsilon: 0.10
# Episode 651 started. Initial State Shape: (6, 10, 10)
# Episode 652 started. Initial State Shape: (6, 10, 10)
# Episode 653 started. Initial State Shape: (6, 10, 10)
# Episode 654 started. Initial State Shape: (6, 10, 10)
# Episode 655 started. Initial State Shape: (6, 10, 10)
# Episode 656 started. Initial State Shape: (6, 10, 10)
# Episode 657 started. Initial State Shape: (6, 10, 10)
# Episode 658 started. Initial State Shape: (6, 10, 10)
# Episode 659 started. Initial State Shape: (6, 10, 10)
# Episode 660 started. Initial State Shape: (6, 10, 10)
# Episode 660: Total Reward: 9, Epsilon: 0.10
# Episode 661 started. Initial State Shape: (6, 10, 10)
# Episode 662 started. Initial State Shape: (6, 10, 10)
# Episode 663 started. Initial State Shape: (6, 10, 10)
# Episode 664 started. Initial State Shape: (6, 10, 10)
# Episode 665 started. Initial State Shape: (6, 10, 10)
# Episode 666 started. Initial State Shape: (6, 10, 10)
# Episode 667 started. Initial State Shape: (6, 10, 10)
# Episode 668 started. Initial State Shape: (6, 10, 10)
# Episode 669 started. Initial State Shape: (6, 10, 10)
# Episode 670 started. Initial State Shape: (6, 10, 10)
# Episode 670: Total Reward: 23, Epsilon: 0.10
# Episode 671 started. Initial State Shape: (6, 10, 10)
# Episode 672 started. Initial State Shape: (6, 10, 10)
# Episode 673 started. Initial State Shape: (6, 10, 10)
# Episode 674 started. Initial State Shape: (6, 10, 10)
# Episode 675 started. Initial State Shape: (6, 10, 10)
# Episode 676 started. Initial State Shape: (6, 10, 10)
# Episode 677 started. Initial State Shape: (6, 10, 10)
# Episode 678 started. Initial State Shape: (6, 10, 10)
# Episode 679 started. Initial State Shape: (6, 10, 10)
# Episode 680 started. Initial State Shape: (6, 10, 10)
# Episode 680: Total Reward: 18, Epsilon: 0.10
# Episode 681 started. Initial State Shape: (6, 10, 10)
# Episode 682 started. Initial State Shape: (6, 10, 10)
# Episode 683 started. Initial State Shape: (6, 10, 10)
# Episode 684 started. Initial State Shape: (6, 10, 10)
# Episode 685 started. Initial State Shape: (6, 10, 10)
# Episode 686 started. Initial State Shape: (6, 10, 10)
# Episode 687 started. Initial State Shape: (6, 10, 10)
# Episode 688 started. Initial State Shape: (6, 10, 10)
# Episode 689 started. Initial State Shape: (6, 10, 10)
# Episode 690 started. Initial State Shape: (6, 10, 10)
# Episode 690: Total Reward: 21, Epsilon: 0.10
# Episode 691 started. Initial State Shape: (6, 10, 10)
# Episode 692 started. Initial State Shape: (6, 10, 10)
# Episode 693 started. Initial State Shape: (6, 10, 10)
# Episode 694 started. Initial State Shape: (6, 10, 10)
# Episode 695 started. Initial State Shape: (6, 10, 10)
# Episode 696 started. Initial State Shape: (6, 10, 10)
# Episode 697 started. Initial State Shape: (6, 10, 10)
# Episode 698 started. Initial State Shape: (6, 10, 10)
# Episode 699 started. Initial State Shape: (6, 10, 10)
# Episode 700 started. Initial State Shape: (6, 10, 10)
# Episode 700: Total Reward: 23, Epsilon: 0.10
# Episode 701 started. Initial State Shape: (6, 10, 10)
# Episode 702 started. Initial State Shape: (6, 10, 10)
# Episode 703 started. Initial State Shape: (6, 10, 10)
# Episode 704 started. Initial State Shape: (6, 10, 10)
# Episode 705 started. Initial State Shape: (6, 10, 10)
# Episode 706 started. Initial State Shape: (6, 10, 10)
# Episode 707 started. Initial State Shape: (6, 10, 10)
# Episode 708 started. Initial State Shape: (6, 10, 10)
# Episode 709 started. Initial State Shape: (6, 10, 10)
# Episode 710 started. Initial State Shape: (6, 10, 10)
# Episode 710: Total Reward: 9, Epsilon: 0.10
# Episode 711 started. Initial State Shape: (6, 10, 10)
# Episode 712 started. Initial State Shape: (6, 10, 10)
# Episode 713 started. Initial State Shape: (6, 10, 10)
# Episode 714 started. Initial State Shape: (6, 10, 10)
# Episode 715 started. Initial State Shape: (6, 10, 10)
# Episode 716 started. Initial State Shape: (6, 10, 10)
# Episode 717 started. Initial State Shape: (6, 10, 10)
# Episode 718 started. Initial State Shape: (6, 10, 10)
# Episode 719 started. Initial State Shape: (6, 10, 10)
# Episode 720 started. Initial State Shape: (6, 10, 10)
# Episode 720: Total Reward: 3, Epsilon: 0.10
# Episode 721 started. Initial State Shape: (6, 10, 10)
# Episode 722 started. Initial State Shape: (6, 10, 10)
# Episode 723 started. Initial State Shape: (6, 10, 10)
# Episode 724 started. Initial State Shape: (6, 10, 10)
# Episode 725 started. Initial State Shape: (6, 10, 10)
# Episode 726 started. Initial State Shape: (6, 10, 10)
# Episode 727 started. Initial State Shape: (6, 10, 10)
# Episode 728 started. Initial State Shape: (6, 10, 10)
# Episode 729 started. Initial State Shape: (6, 10, 10)
# Episode 730 started. Initial State Shape: (6, 10, 10)
# Episode 730: Total Reward: 22, Epsilon: 0.10
# Episode 731 started. Initial State Shape: (6, 10, 10)
# Episode 732 started. Initial State Shape: (6, 10, 10)
# Episode 733 started. Initial State Shape: (6, 10, 10)
# Episode 734 started. Initial State Shape: (6, 10, 10)
# Episode 735 started. Initial State Shape: (6, 10, 10)
# Episode 736 started. Initial State Shape: (6, 10, 10)
# Episode 737 started. Initial State Shape: (6, 10, 10)
# Episode 738 started. Initial State Shape: (6, 10, 10)
# Episode 739 started. Initial State Shape: (6, 10, 10)
# Episode 740 started. Initial State Shape: (6, 10, 10)
# Episode 740: Total Reward: 13, Epsilon: 0.10
# Episode 741 started. Initial State Shape: (6, 10, 10)
# Episode 742 started. Initial State Shape: (6, 10, 10)
# Episode 743 started. Initial State Shape: (6, 10, 10)
# Episode 744 started. Initial State Shape: (6, 10, 10)
# Episode 745 started. Initial State Shape: (6, 10, 10)
# Episode 746 started. Initial State Shape: (6, 10, 10)
# Episode 747 started. Initial State Shape: (6, 10, 10)
# Episode 748 started. Initial State Shape: (6, 10, 10)
# Episode 749 started. Initial State Shape: (6, 10, 10)
# Episode 750 started. Initial State Shape: (6, 10, 10)
# Episode 750: Total Reward: 23, Epsilon: 0.10
# Episode 751 started. Initial State Shape: (6, 10, 10)
# Episode 752 started. Initial State Shape: (6, 10, 10)
# Episode 753 started. Initial State Shape: (6, 10, 10)
# Episode 754 started. Initial State Shape: (6, 10, 10)
# Episode 755 started. Initial State Shape: (6, 10, 10)
# Episode 756 started. Initial State Shape: (6, 10, 10)
# Episode 757 started. Initial State Shape: (6, 10, 10)
# Episode 758 started. Initial State Shape: (6, 10, 10)
# Episode 759 started. Initial State Shape: (6, 10, 10)
# Episode 760 started. Initial State Shape: (6, 10, 10)
# Episode 760: Total Reward: 23, Epsilon: 0.10
# Episode 761 started. Initial State Shape: (6, 10, 10)
# Episode 762 started. Initial State Shape: (6, 10, 10)
# Episode 763 started. Initial State Shape: (6, 10, 10)
# Episode 764 started. Initial State Shape: (6, 10, 10)
# Episode 765 started. Initial State Shape: (6, 10, 10)
# Episode 766 started. Initial State Shape: (6, 10, 10)
# Episode 767 started. Initial State Shape: (6, 10, 10)
# Episode 768 started. Initial State Shape: (6, 10, 10)
# Episode 769 started. Initial State Shape: (6, 10, 10)
# Episode 770 started. Initial State Shape: (6, 10, 10)
# Episode 770: Total Reward: 19, Epsilon: 0.10
# Episode 771 started. Initial State Shape: (6, 10, 10)
# Episode 772 started. Initial State Shape: (6, 10, 10)
# Episode 773 started. Initial State Shape: (6, 10, 10)
# Episode 774 started. Initial State Shape: (6, 10, 10)
# Episode 775 started. Initial State Shape: (6, 10, 10)
# Episode 776 started. Initial State Shape: (6, 10, 10)
# Episode 777 started. Initial State Shape: (6, 10, 10)
# Episode 778 started. Initial State Shape: (6, 10, 10)
# Episode 779 started. Initial State Shape: (6, 10, 10)
# Episode 780 started. Initial State Shape: (6, 10, 10)
# Episode 780: Total Reward: 21, Epsilon: 0.10
# Episode 781 started. Initial State Shape: (6, 10, 10)
# Episode 782 started. Initial State Shape: (6, 10, 10)
# Episode 783 started. Initial State Shape: (6, 10, 10)
# Episode 784 started. Initial State Shape: (6, 10, 10)
# Episode 785 started. Initial State Shape: (6, 10, 10)
# Episode 786 started. Initial State Shape: (6, 10, 10)
# Episode 787 started. Initial State Shape: (6, 10, 10)
# Episode 788 started. Initial State Shape: (6, 10, 10)
# Episode 789 started. Initial State Shape: (6, 10, 10)
# Episode 790 started. Initial State Shape: (6, 10, 10)
# Episode 790: Total Reward: 22, Epsilon: 0.10
# Episode 791 started. Initial State Shape: (6, 10, 10)
# Episode 792 started. Initial State Shape: (6, 10, 10)
# Episode 793 started. Initial State Shape: (6, 10, 10)
# Episode 794 started. Initial State Shape: (6, 10, 10)
# Episode 795 started. Initial State Shape: (6, 10, 10)
# Episode 796 started. Initial State Shape: (6, 10, 10)
# Episode 797 started. Initial State Shape: (6, 10, 10)
# Episode 798 started. Initial State Shape: (6, 10, 10)
# Episode 799 started. Initial State Shape: (6, 10, 10)
# Episode 800 started. Initial State Shape: (6, 10, 10)
# Episode 800: Total Reward: 16, Epsilon: 0.10
# Episode 801 started. Initial State Shape: (6, 10, 10)
# Episode 802 started. Initial State Shape: (6, 10, 10)
# Episode 803 started. Initial State Shape: (6, 10, 10)
# Episode 804 started. Initial State Shape: (6, 10, 10)
# Episode 805 started. Initial State Shape: (6, 10, 10)
# Episode 806 started. Initial State Shape: (6, 10, 10)
# Episode 807 started. Initial State Shape: (6, 10, 10)
# Episode 808 started. Initial State Shape: (6, 10, 10)
# Episode 809 started. Initial State Shape: (6, 10, 10)
# Episode 810 started. Initial State Shape: (6, 10, 10)
# Episode 810: Total Reward: 9, Epsilon: 0.10
# Episode 811 started. Initial State Shape: (6, 10, 10)
# Episode 812 started. Initial State Shape: (6, 10, 10)
# Episode 813 started. Initial State Shape: (6, 10, 10)
# Episode 814 started. Initial State Shape: (6, 10, 10)
# Episode 815 started. Initial State Shape: (6, 10, 10)
# Episode 816 started. Initial State Shape: (6, 10, 10)
# Episode 817 started. Initial State Shape: (6, 10, 10)
# Episode 818 started. Initial State Shape: (6, 10, 10)
# Episode 819 started. Initial State Shape: (6, 10, 10)
# Episode 820 started. Initial State Shape: (6, 10, 10)
# Episode 820: Total Reward: 22, Epsilon: 0.10
# Episode 821 started. Initial State Shape: (6, 10, 10)
# Episode 822 started. Initial State Shape: (6, 10, 10)
# Episode 823 started. Initial State Shape: (6, 10, 10)
# Episode 824 started. Initial State Shape: (6, 10, 10)
# Episode 825 started. Initial State Shape: (6, 10, 10)
# Episode 826 started. Initial State Shape: (6, 10, 10)
# Episode 827 started. Initial State Shape: (6, 10, 10)
# Episode 828 started. Initial State Shape: (6, 10, 10)
# Episode 829 started. Initial State Shape: (6, 10, 10)
# Episode 830 started. Initial State Shape: (6, 10, 10)
# Episode 830: Total Reward: 5, Epsilon: 0.10
# Episode 831 started. Initial State Shape: (6, 10, 10)
# Episode 832 started. Initial State Shape: (6, 10, 10)
# Episode 833 started. Initial State Shape: (6, 10, 10)
# Episode 834 started. Initial State Shape: (6, 10, 10)
# Episode 835 started. Initial State Shape: (6, 10, 10)
# Episode 836 started. Initial State Shape: (6, 10, 10)
# Episode 837 started. Initial State Shape: (6, 10, 10)
# Episode 838 started. Initial State Shape: (6, 10, 10)
# Episode 839 started. Initial State Shape: (6, 10, 10)
# Episode 840 started. Initial State Shape: (6, 10, 10)
# Episode 840: Total Reward: 22, Epsilon: 0.10
# Episode 841 started. Initial State Shape: (6, 10, 10)
# Episode 842 started. Initial State Shape: (6, 10, 10)
# Episode 843 started. Initial State Shape: (6, 10, 10)
# Episode 844 started. Initial State Shape: (6, 10, 10)
# Episode 845 started. Initial State Shape: (6, 10, 10)
# Episode 846 started. Initial State Shape: (6, 10, 10)
# Episode 847 started. Initial State Shape: (6, 10, 10)
# Episode 848 started. Initial State Shape: (6, 10, 10)
# Episode 849 started. Initial State Shape: (6, 10, 10)
# Episode 850 started. Initial State Shape: (6, 10, 10)
# Episode 850: Total Reward: 4, Epsilon: 0.10
# Episode 851 started. Initial State Shape: (6, 10, 10)
# Episode 852 started. Initial State Shape: (6, 10, 10)
# Episode 853 started. Initial State Shape: (6, 10, 10)
# Episode 854 started. Initial State Shape: (6, 10, 10)
# Episode 855 started. Initial State Shape: (6, 10, 10)
# Episode 856 started. Initial State Shape: (6, 10, 10)
# Episode 857 started. Initial State Shape: (6, 10, 10)
# Episode 858 started. Initial State Shape: (6, 10, 10)
# Episode 859 started. Initial State Shape: (6, 10, 10)
# Episode 860 started. Initial State Shape: (6, 10, 10)
# Episode 860: Total Reward: 23, Epsilon: 0.10
# Episode 861 started. Initial State Shape: (6, 10, 10)
# Episode 862 started. Initial State Shape: (6, 10, 10)
# Episode 863 started. Initial State Shape: (6, 10, 10)
# Episode 864 started. Initial State Shape: (6, 10, 10)
# Episode 865 started. Initial State Shape: (6, 10, 10)
# Episode 866 started. Initial State Shape: (6, 10, 10)
# Episode 867 started. Initial State Shape: (6, 10, 10)
# Episode 868 started. Initial State Shape: (6, 10, 10)
# Episode 869 started. Initial State Shape: (6, 10, 10)
# Episode 870 started. Initial State Shape: (6, 10, 10)
# Episode 870: Total Reward: 19, Epsilon: 0.10
# Episode 871 started. Initial State Shape: (6, 10, 10)
# Episode 872 started. Initial State Shape: (6, 10, 10)
# Episode 873 started. Initial State Shape: (6, 10, 10)
# Episode 874 started. Initial State Shape: (6, 10, 10)
# Episode 875 started. Initial State Shape: (6, 10, 10)
# Episode 876 started. Initial State Shape: (6, 10, 10)
# Episode 877 started. Initial State Shape: (6, 10, 10)
# Episode 878 started. Initial State Shape: (6, 10, 10)
# Episode 879 started. Initial State Shape: (6, 10, 10)
# Episode 880 started. Initial State Shape: (6, 10, 10)
# Episode 880: Total Reward: 23, Epsilon: 0.10
# Episode 881 started. Initial State Shape: (6, 10, 10)
# Episode 882 started. Initial State Shape: (6, 10, 10)
# Episode 883 started. Initial State Shape: (6, 10, 10)
# Episode 884 started. Initial State Shape: (6, 10, 10)
# Episode 885 started. Initial State Shape: (6, 10, 10)
# Episode 886 started. Initial State Shape: (6, 10, 10)
# Episode 887 started. Initial State Shape: (6, 10, 10)
# Episode 888 started. Initial State Shape: (6, 10, 10)
# Episode 889 started. Initial State Shape: (6, 10, 10)
# Episode 890 started. Initial State Shape: (6, 10, 10)
# Episode 890: Total Reward: 19, Epsilon: 0.10
# Episode 891 started. Initial State Shape: (6, 10, 10)
# Episode 892 started. Initial State Shape: (6, 10, 10)
# Episode 893 started. Initial State Shape: (6, 10, 10)
# Episode 894 started. Initial State Shape: (6, 10, 10)
# Episode 895 started. Initial State Shape: (6, 10, 10)
# Episode 896 started. Initial State Shape: (6, 10, 10)
# Episode 897 started. Initial State Shape: (6, 10, 10)
# Episode 898 started. Initial State Shape: (6, 10, 10)
# Episode 899 started. Initial State Shape: (6, 10, 10)
# Episode 900 started. Initial State Shape: (6, 10, 10)
# Episode 900: Total Reward: 23, Epsilon: 0.10
# Episode 901 started. Initial State Shape: (6, 10, 10)
# Episode 902 started. Initial State Shape: (6, 10, 10)
# Episode 903 started. Initial State Shape: (6, 10, 10)
# Episode 904 started. Initial State Shape: (6, 10, 10)
# Episode 905 started. Initial State Shape: (6, 10, 10)
# Episode 906 started. Initial State Shape: (6, 10, 10)
# Episode 907 started. Initial State Shape: (6, 10, 10)
# Episode 908 started. Initial State Shape: (6, 10, 10)
# Episode 909 started. Initial State Shape: (6, 10, 10)
# Episode 910 started. Initial State Shape: (6, 10, 10)
# Episode 910: Total Reward: 4, Epsilon: 0.10
# Episode 911 started. Initial State Shape: (6, 10, 10)
# Episode 912 started. Initial State Shape: (6, 10, 10)
# Episode 913 started. Initial State Shape: (6, 10, 10)
# Episode 914 started. Initial State Shape: (6, 10, 10)
# Episode 915 started. Initial State Shape: (6, 10, 10)
# Episode 916 started. Initial State Shape: (6, 10, 10)
# Episode 917 started. Initial State Shape: (6, 10, 10)
# Episode 918 started. Initial State Shape: (6, 10, 10)
# Episode 919 started. Initial State Shape: (6, 10, 10)
# Episode 920 started. Initial State Shape: (6, 10, 10)
# Episode 920: Total Reward: 21, Epsilon: 0.10
# Episode 921 started. Initial State Shape: (6, 10, 10)
# Episode 922 started. Initial State Shape: (6, 10, 10)
# Episode 923 started. Initial State Shape: (6, 10, 10)
# Episode 924 started. Initial State Shape: (6, 10, 10)
# Episode 925 started. Initial State Shape: (6, 10, 10)
# Episode 926 started. Initial State Shape: (6, 10, 10)
# Episode 927 started. Initial State Shape: (6, 10, 10)
# Episode 928 started. Initial State Shape: (6, 10, 10)
# Episode 929 started. Initial State Shape: (6, 10, 10)
# Episode 930 started. Initial State Shape: (6, 10, 10)
# Episode 930: Total Reward: 56, Epsilon: 0.10
# Episode 931 started. Initial State Shape: (6, 10, 10)
# Episode 932 started. Initial State Shape: (6, 10, 10)
# Episode 933 started. Initial State Shape: (6, 10, 10)
# Episode 934 started. Initial State Shape: (6, 10, 10)
# Episode 935 started. Initial State Shape: (6, 10, 10)
# Episode 936 started. Initial State Shape: (6, 10, 10)
# Episode 937 started. Initial State Shape: (6, 10, 10)
# Episode 938 started. Initial State Shape: (6, 10, 10)
# Episode 939 started. Initial State Shape: (6, 10, 10)
# Episode 940 started. Initial State Shape: (6, 10, 10)
# Episode 940: Total Reward: 5, Epsilon: 0.10
# Episode 941 started. Initial State Shape: (6, 10, 10)
# Episode 942 started. Initial State Shape: (6, 10, 10)
# Episode 943 started. Initial State Shape: (6, 10, 10)
# Episode 944 started. Initial State Shape: (6, 10, 10)
# Episode 945 started. Initial State Shape: (6, 10, 10)
# Episode 946 started. Initial State Shape: (6, 10, 10)
# Episode 947 started. Initial State Shape: (6, 10, 10)
# Episode 948 started. Initial State Shape: (6, 10, 10)
# Episode 949 started. Initial State Shape: (6, 10, 10)
# Episode 950 started. Initial State Shape: (6, 10, 10)
# Episode 950: Total Reward: 23, Epsilon: 0.10
# Episode 951 started. Initial State Shape: (6, 10, 10)
# Episode 952 started. Initial State Shape: (6, 10, 10)
# Episode 953 started. Initial State Shape: (6, 10, 10)
# Episode 954 started. Initial State Shape: (6, 10, 10)
# Episode 955 started. Initial State Shape: (6, 10, 10)
# Episode 956 started. Initial State Shape: (6, 10, 10)
# Episode 957 started. Initial State Shape: (6, 10, 10)
# Episode 958 started. Initial State Shape: (6, 10, 10)
# Episode 959 started. Initial State Shape: (6, 10, 10)
# Episode 960 started. Initial State Shape: (6, 10, 10)
# Episode 960: Total Reward: 19, Epsilon: 0.10
# Episode 961 started. Initial State Shape: (6, 10, 10)
# Episode 962 started. Initial State Shape: (6, 10, 10)
# Episode 963 started. Initial State Shape: (6, 10, 10)
# Episode 964 started. Initial State Shape: (6, 10, 10)
# Episode 965 started. Initial State Shape: (6, 10, 10)
# Episode 966 started. Initial State Shape: (6, 10, 10)
# Episode 967 started. Initial State Shape: (6, 10, 10)
# Episode 968 started. Initial State Shape: (6, 10, 10)
# Episode 969 started. Initial State Shape: (6, 10, 10)
# Episode 970 started. Initial State Shape: (6, 10, 10)
# Episode 970: Total Reward: 9, Epsilon: 0.10
# Episode 971 started. Initial State Shape: (6, 10, 10)
# Episode 972 started. Initial State Shape: (6, 10, 10)
# Episode 973 started. Initial State Shape: (6, 10, 10)
# Episode 974 started. Initial State Shape: (6, 10, 10)
# Episode 975 started. Initial State Shape: (6, 10, 10)
# Episode 976 started. Initial State Shape: (6, 10, 10)
# Episode 977 started. Initial State Shape: (6, 10, 10)
# Episode 978 started. Initial State Shape: (6, 10, 10)
# Episode 979 started. Initial State Shape: (6, 10, 10)
# Episode 980 started. Initial State Shape: (6, 10, 10)
# Episode 980: Total Reward: 23, Epsilon: 0.10
# Episode 981 started. Initial State Shape: (6, 10, 10)
# Episode 982 started. Initial State Shape: (6, 10, 10)
# Episode 983 started. Initial State Shape: (6, 10, 10)
# Episode 984 started. Initial State Shape: (6, 10, 10)
# Episode 985 started. Initial State Shape: (6, 10, 10)
# Episode 986 started. Initial State Shape: (6, 10, 10)
# Episode 987 started. Initial State Shape: (6, 10, 10)
# Episode 988 started. Initial State Shape: (6, 10, 10)
# Episode 989 started. Initial State Shape: (6, 10, 10)
# Episode 990 started. Initial State Shape: (6, 10, 10)
# Episode 990: Total Reward: 23, Epsilon: 0.10
# Episode 991 started. Initial State Shape: (6, 10, 10)
# Episode 992 started. Initial State Shape: (6, 10, 10)
# Episode 993 started. Initial State Shape: (6, 10, 10)
# Episode 994 started. Initial State Shape: (6, 10, 10)
# Episode 995 started. Initial State Shape: (6, 10, 10)
# Episode 996 started. Initial State Shape: (6, 10, 10)
# Episode 997 started. Initial State Shape: (6, 10, 10)
# Episode 998 started. Initial State Shape: (6, 10, 10)
# Episode 999 started. Initial State Shape: (6, 10, 10)
# Episode 1000 started. Initial State Shape: (6, 10, 10)
# Episode 1000: Total Reward: 22, Epsilon: 0.10
# Episode 1001 started. Initial State Shape: (6, 10, 10)
# Episode 1002 started. Initial State Shape: (6, 10, 10)
# Episode 1003 started. Initial State Shape: (6, 10, 10)
# Episode 1004 started. Initial State Shape: (6, 10, 10)
# Episode 1005 started. Initial State Shape: (6, 10, 10)
# Episode 1006 started. Initial State Shape: (6, 10, 10)
# Episode 1007 started. Initial State Shape: (6, 10, 10)
# Episode 1008 started. Initial State Shape: (6, 10, 10)
# Episode 1009 started. Initial State Shape: (6, 10, 10)
# Episode 1010 started. Initial State Shape: (6, 10, 10)
# Episode 1010: Total Reward: 23, Epsilon: 0.10
# Episode 1011 started. Initial State Shape: (6, 10, 10)
# Episode 1012 started. Initial State Shape: (6, 10, 10)
# Episode 1013 started. Initial State Shape: (6, 10, 10)
# Episode 1014 started. Initial State Shape: (6, 10, 10)
# Episode 1015 started. Initial State Shape: (6, 10, 10)
# Episode 1016 started. Initial State Shape: (6, 10, 10)
# Episode 1017 started. Initial State Shape: (6, 10, 10)
# Episode 1018 started. Initial State Shape: (6, 10, 10)
# Episode 1019 started. Initial State Shape: (6, 10, 10)
# Episode 1020 started. Initial State Shape: (6, 10, 10)
# Episode 1020: Total Reward: 20, Epsilon: 0.10
# Episode 1021 started. Initial State Shape: (6, 10, 10)
# Episode 1022 started. Initial State Shape: (6, 10, 10)
# Episode 1023 started. Initial State Shape: (6, 10, 10)
# Episode 1024 started. Initial State Shape: (6, 10, 10)
# Episode 1025 started. Initial State Shape: (6, 10, 10)
# Episode 1026 started. Initial State Shape: (6, 10, 10)
# Episode 1027 started. Initial State Shape: (6, 10, 10)
# ...
# Episode 4486 started. Initial State Shape: (6, 10, 10)
# Episode 4487 started. Initial State Shape: (6, 10, 10)
# Episode 4488 started. Initial State Shape: (6, 10, 10)
# Episode 4489 started. Initial State Shape: (6, 10, 10)
# Episode 4490 started. Initial State Shape: (6, 10, 10)
# Episode 4490: Total Reward: 4, Epsilon: 0.10
# Episode 4491 started. Initial State Shape: (6, 10, 10)
# Episode 4492 started. Initial State Shape: (6, 10, 10)
# Episode 4493 started. Initial State Shape: (6, 10, 10)
# Episode 4494 started. Initial State Shape: (6, 10, 10)
# Episode 4495 started. Initial State Shape: (6, 10, 10)
# Episode 4496 started. Initial State Shape: (6, 10, 10)
# Episode 4497 started. Initial State Shape: (6, 10, 10)
# Episode 4498 started. Initial State Shape: (6, 10, 10)
# Episode 4499 started. Initial State Shape: (6, 10, 10)
# Episode 4500 started. Initial State Shape: (6, 10, 10)
# Episode 4500: Total Reward: 23, Epsilon: 0.10
# Episode 4501 started. Initial State Shape: (6, 10, 10)
# Episode 4502 started. Initial State Shape: (6, 10, 10)
# Episode 4503 started. Initial State Shape: (6, 10, 10)
# Episode 4504 started. Initial State Shape: (6, 10, 10)
# Episode 4505 started. Initial State Shape: (6, 10, 10)
# Episode 4506 started. Initial State Shape: (6, 10, 10)
# Episode 4507 started. Initial State Shape: (6, 10, 10)
# Episode 4508 started. Initial State Shape: (6, 10, 10)
# Episode 4509 started. Initial State Shape: (6, 10, 10)
# Episode 4510 started. Initial State Shape: (6, 10, 10)
# Episode 4510: Total Reward: 17, Epsilon: 0.10
# Episode 4511 started. Initial State Shape: (6, 10, 10)
# Episode 4512 started. Initial State Shape: (6, 10, 10)
# Episode 4513 started. Initial State Shape: (6, 10, 10)
# Episode 4514 started. Initial State Shape: (6, 10, 10)
# Episode 4515 started. Initial State Shape: (6, 10, 10)
# Episode 4516 started. Initial State Shape: (6, 10, 10)
# Episode 4517 started. Initial State Shape: (6, 10, 10)
# Episode 4518 started. Initial State Shape: (6, 10, 10)
# Episode 4519 started. Initial State Shape: (6, 10, 10)
# Episode 4520 started. Initial State Shape: (6, 10, 10)
# Episode 4520: Total Reward: 15, Epsilon: 0.10
# Episode 4521 started. Initial State Shape: (6, 10, 10)
# Episode 4522 started. Initial State Shape: (6, 10, 10)
# Episode 4523 started. Initial State Shape: (6, 10, 10)
# Episode 4524 started. Initial State Shape: (6, 10, 10)
# Episode 4525 started. Initial State Shape: (6, 10, 10)
# Episode 4526 started. Initial State Shape: (6, 10, 10)
# Episode 4527 started. Initial State Shape: (6, 10, 10)
# Episode 4528 started. Initial State Shape: (6, 10, 10)
# Episode 4529 started. Initial State Shape: (6, 10, 10)
# Episode 4530 started. Initial State Shape: (6, 10, 10)
# Episode 4530: Total Reward: 1, Epsilon: 0.10
# Episode 4531 started. Initial State Shape: (6, 10, 10)
# Episode 4532 started. Initial State Shape: (6, 10, 10)
# Episode 4533 started. Initial State Shape: (6, 10, 10)
# Episode 4534 started. Initial State Shape: (6, 10, 10)
# Episode 4535 started. Initial State Shape: (6, 10, 10)
# Episode 4536 started. Initial State Shape: (6, 10, 10)
# Episode 4537 started. Initial State Shape: (6, 10, 10)
# Episode 4538 started. Initial State Shape: (6, 10, 10)
# Episode 4539 started. Initial State Shape: (6, 10, 10)
# Episode 4540 started. Initial State Shape: (6, 10, 10)
# Episode 4540: Total Reward: 10, Epsilon: 0.10
# Episode 4541 started. Initial State Shape: (6, 10, 10)
# Episode 4542 started. Initial State Shape: (6, 10, 10)
# Episode 4543 started. Initial State Shape: (6, 10, 10)
# Episode 4544 started. Initial State Shape: (6, 10, 10)
# Episode 4545 started. Initial State Shape: (6, 10, 10)
# Episode 4546 started. Initial State Shape: (6, 10, 10)
# Episode 4547 started. Initial State Shape: (6, 10, 10)
# Episode 4548 started. Initial State Shape: (6, 10, 10)
# Episode 4549 started. Initial State Shape: (6, 10, 10)
# Episode 4550 started. Initial State Shape: (6, 10, 10)
# Episode 4550: Total Reward: 18, Epsilon: 0.10
# Episode 4551 started. Initial State Shape: (6, 10, 10)
# Episode 4552 started. Initial State Shape: (6, 10, 10)
# Episode 4553 started. Initial State Shape: (6, 10, 10)
# Episode 4554 started. Initial State Shape: (6, 10, 10)
# Episode 4555 started. Initial State Shape: (6, 10, 10)
# Episode 4556 started. Initial State Shape: (6, 10, 10)
# Episode 4557 started. Initial State Shape: (6, 10, 10)
# Episode 4558 started. Initial State Shape: (6, 10, 10)
# Episode 4559 started. Initial State Shape: (6, 10, 10)
# Episode 4560 started. Initial State Shape: (6, 10, 10)
# Episode 4560: Total Reward: 9, Epsilon: 0.10
# Episode 4561 started. Initial State Shape: (6, 10, 10)
# Episode 4562 started. Initial State Shape: (6, 10, 10)
# Episode 4563 started. Initial State Shape: (6, 10, 10)
# Episode 4564 started. Initial State Shape: (6, 10, 10)
# Episode 4565 started. Initial State Shape: (6, 10, 10)
# Episode 4566 started. Initial State Shape: (6, 10, 10)
# Episode 4567 started. Initial State Shape: (6, 10, 10)
# Episode 4568 started. Initial State Shape: (6, 10, 10)
# Episode 4569 started. Initial State Shape: (6, 10, 10)
# Episode 4570 started. Initial State Shape: (6, 10, 10)
# Episode 4570: Total Reward: 22, Epsilon: 0.10
# Episode 4571 started. Initial State Shape: (6, 10, 10)
# Episode 4572 started. Initial State Shape: (6, 10, 10)
# Episode 4573 started. Initial State Shape: (6, 10, 10)
# Episode 4574 started. Initial State Shape: (6, 10, 10)
# Episode 4575 started. Initial State Shape: (6, 10, 10)
# Episode 4576 started. Initial State Shape: (6, 10, 10)
# Episode 4577 started. Initial State Shape: (6, 10, 10)
# Episode 4578 started. Initial State Shape: (6, 10, 10)
# Episode 4579 started. Initial State Shape: (6, 10, 10)
# Episode 4580 started. Initial State Shape: (6, 10, 10)
# Episode 4580: Total Reward: 8, Epsilon: 0.10
# Episode 4581 started. Initial State Shape: (6, 10, 10)
# Episode 4582 started. Initial State Shape: (6, 10, 10)
# Episode 4583 started. Initial State Shape: (6, 10, 10)
# Episode 4584 started. Initial State Shape: (6, 10, 10)
# Episode 4585 started. Initial State Shape: (6, 10, 10)
# Episode 4586 started. Initial State Shape: (6, 10, 10)
# Episode 4587 started. Initial State Shape: (6, 10, 10)
# Episode 4588 started. Initial State Shape: (6, 10, 10)
# Episode 4589 started. Initial State Shape: (6, 10, 10)
# Episode 4590 started. Initial State Shape: (6, 10, 10)
# Episode 4590: Total Reward: 22, Epsilon: 0.10
# Episode 4591 started. Initial State Shape: (6, 10, 10)
# Episode 4592 started. Initial State Shape: (6, 10, 10)
# Episode 4593 started. Initial State Shape: (6, 10, 10)
# Episode 4594 started. Initial State Shape: (6, 10, 10)
# Episode 4595 started. Initial State Shape: (6, 10, 10)
# Episode 4596 started. Initial State Shape: (6, 10, 10)
# Episode 4597 started. Initial State Shape: (6, 10, 10)
# Episode 4598 started. Initial State Shape: (6, 10, 10)
# Episode 4599 started. Initial State Shape: (6, 10, 10)
# Episode 4600 started. Initial State Shape: (6, 10, 10)
# Episode 4600: Total Reward: 20, Epsilon: 0.10
# Episode 4601 started. Initial State Shape: (6, 10, 10)
# Episode 4602 started. Initial State Shape: (6, 10, 10)
# Episode 4603 started. Initial State Shape: (6, 10, 10)
# Episode 4604 started. Initial State Shape: (6, 10, 10)
# Episode 4605 started. Initial State Shape: (6, 10, 10)
# Episode 4606 started. Initial State Shape: (6, 10, 10)
# Episode 4607 started. Initial State Shape: (6, 10, 10)
# Episode 4608 started. Initial State Shape: (6, 10, 10)
# Episode 4609 started. Initial State Shape: (6, 10, 10)
# Episode 4610 started. Initial State Shape: (6, 10, 10)
# Episode 4610: Total Reward: 10, Epsilon: 0.10
# Episode 4611 started. Initial State Shape: (6, 10, 10)
# Episode 4612 started. Initial State Shape: (6, 10, 10)
# Episode 4613 started. Initial State Shape: (6, 10, 10)
# Episode 4614 started. Initial State Shape: (6, 10, 10)
# Episode 4615 started. Initial State Shape: (6, 10, 10)
# Episode 4616 started. Initial State Shape: (6, 10, 10)
# Episode 4617 started. Initial State Shape: (6, 10, 10)
# Episode 4618 started. Initial State Shape: (6, 10, 10)
# Episode 4619 started. Initial State Shape: (6, 10, 10)
# Episode 4620 started. Initial State Shape: (6, 10, 10)
# Episode 4620: Total Reward: 6, Epsilon: 0.10
# Episode 4621 started. Initial State Shape: (6, 10, 10)
# Episode 4622 started. Initial State Shape: (6, 10, 10)
# Episode 4623 started. Initial State Shape: (6, 10, 10)
# Episode 4624 started. Initial State Shape: (6, 10, 10)
# Episode 4625 started. Initial State Shape: (6, 10, 10)
# Episode 4626 started. Initial State Shape: (6, 10, 10)
# Episode 4627 started. Initial State Shape: (6, 10, 10)
# Episode 4628 started. Initial State Shape: (6, 10, 10)
# Episode 4629 started. Initial State Shape: (6, 10, 10)
# Episode 4630 started. Initial State Shape: (6, 10, 10)
# Episode 4630: Total Reward: 6, Epsilon: 0.10
# Episode 4631 started. Initial State Shape: (6, 10, 10)
# Episode 4632 started. Initial State Shape: (6, 10, 10)
# Episode 4633 started. Initial State Shape: (6, 10, 10)
# Episode 4634 started. Initial State Shape: (6, 10, 10)
# Episode 4635 started. Initial State Shape: (6, 10, 10)
# Episode 4636 started. Initial State Shape: (6, 10, 10)
# Episode 4637 started. Initial State Shape: (6, 10, 10)
# Episode 4638 started. Initial State Shape: (6, 10, 10)
# Episode 4639 started. Initial State Shape: (6, 10, 10)
# Episode 4640 started. Initial State Shape: (6, 10, 10)
# Episode 4640: Total Reward: 11, Epsilon: 0.10
# Episode 4641 started. Initial State Shape: (6, 10, 10)
# Episode 4642 started. Initial State Shape: (6, 10, 10)
# Episode 4643 started. Initial State Shape: (6, 10, 10)
# Episode 4644 started. Initial State Shape: (6, 10, 10)
# Episode 4645 started. Initial State Shape: (6, 10, 10)
# Episode 4646 started. Initial State Shape: (6, 10, 10)
# Episode 4647 started. Initial State Shape: (6, 10, 10)
# Episode 4648 started. Initial State Shape: (6, 10, 10)
# Episode 4649 started. Initial State Shape: (6, 10, 10)
# Episode 4650 started. Initial State Shape: (6, 10, 10)
# Episode 4650: Total Reward: 22, Epsilon: 0.10
# Episode 4651 started. Initial State Shape: (6, 10, 10)
# Episode 4652 started. Initial State Shape: (6, 10, 10)
# Episode 4653 started. Initial State Shape: (6, 10, 10)
# Episode 4654 started. Initial State Shape: (6, 10, 10)
# Episode 4655 started. Initial State Shape: (6, 10, 10)
# Episode 4656 started. Initial State Shape: (6, 10, 10)
# Episode 4657 started. Initial State Shape: (6, 10, 10)
# Episode 4658 started. Initial State Shape: (6, 10, 10)
# Episode 4659 started. Initial State Shape: (6, 10, 10)
# Episode 4660 started. Initial State Shape: (6, 10, 10)
# Episode 4660: Total Reward: 2, Epsilon: 0.10
# Episode 4661 started. Initial State Shape: (6, 10, 10)
# Episode 4662 started. Initial State Shape: (6, 10, 10)
# Episode 4663 started. Initial State Shape: (6, 10, 10)
# Episode 4664 started. Initial State Shape: (6, 10, 10)
# Episode 4665 started. Initial State Shape: (6, 10, 10)
# Episode 4666 started. Initial State Shape: (6, 10, 10)
# Episode 4667 started. Initial State Shape: (6, 10, 10)
# Episode 4668 started. Initial State Shape: (6, 10, 10)
# Episode 4669 started. Initial State Shape: (6, 10, 10)
# Episode 4670 started. Initial State Shape: (6, 10, 10)
# Episode 4670: Total Reward: 16, Epsilon: 0.10
# Episode 4671 started. Initial State Shape: (6, 10, 10)
# Episode 4672 started. Initial State Shape: (6, 10, 10)
# Episode 4673 started. Initial State Shape: (6, 10, 10)
# Episode 4674 started. Initial State Shape: (6, 10, 10)
# Episode 4675 started. Initial State Shape: (6, 10, 10)
# Episode 4676 started. Initial State Shape: (6, 10, 10)
# Episode 4677 started. Initial State Shape: (6, 10, 10)
# Episode 4678 started. Initial State Shape: (6, 10, 10)
# Episode 4679 started. Initial State Shape: (6, 10, 10)
# Episode 4680 started. Initial State Shape: (6, 10, 10)
# Episode 4680: Total Reward: 6, Epsilon: 0.10
# Episode 4681 started. Initial State Shape: (6, 10, 10)
# Episode 4682 started. Initial State Shape: (6, 10, 10)
# Episode 4683 started. Initial State Shape: (6, 10, 10)
# Episode 4684 started. Initial State Shape: (6, 10, 10)
# Episode 4685 started. Initial State Shape: (6, 10, 10)
# Episode 4686 started. Initial State Shape: (6, 10, 10)
# Episode 4687 started. Initial State Shape: (6, 10, 10)
# Episode 4688 started. Initial State Shape: (6, 10, 10)
# Episode 4689 started. Initial State Shape: (6, 10, 10)
# Episode 4690 started. Initial State Shape: (6, 10, 10)
# Episode 4690: Total Reward: 20, Epsilon: 0.10
# Episode 4691 started. Initial State Shape: (6, 10, 10)
# Episode 4692 started. Initial State Shape: (6, 10, 10)
# Episode 4693 started. Initial State Shape: (6, 10, 10)
# Episode 4694 started. Initial State Shape: (6, 10, 10)
# Episode 4695 started. Initial State Shape: (6, 10, 10)
# Episode 4696 started. Initial State Shape: (6, 10, 10)
# Episode 4697 started. Initial State Shape: (6, 10, 10)
# Episode 4698 started. Initial State Shape: (6, 10, 10)
# Episode 4699 started. Initial State Shape: (6, 10, 10)
# Episode 4700 started. Initial State Shape: (6, 10, 10)
# Episode 4700: Total Reward: 23, Epsilon: 0.10
# Episode 4701 started. Initial State Shape: (6, 10, 10)
# Episode 4702 started. Initial State Shape: (6, 10, 10)
# Episode 4703 started. Initial State Shape: (6, 10, 10)
# Episode 4704 started. Initial State Shape: (6, 10, 10)
# Episode 4705 started. Initial State Shape: (6, 10, 10)
# Episode 4706 started. Initial State Shape: (6, 10, 10)
# Episode 4707 started. Initial State Shape: (6, 10, 10)
# Episode 4708 started. Initial State Shape: (6, 10, 10)
# Episode 4709 started. Initial State Shape: (6, 10, 10)
# Episode 4710 started. Initial State Shape: (6, 10, 10)
# Episode 4710: Total Reward: 20, Epsilon: 0.10
# Episode 4711 started. Initial State Shape: (6, 10, 10)
# Episode 4712 started. Initial State Shape: (6, 10, 10)
# Episode 4713 started. Initial State Shape: (6, 10, 10)
# Episode 4714 started. Initial State Shape: (6, 10, 10)
# Episode 4715 started. Initial State Shape: (6, 10, 10)
# Episode 4716 started. Initial State Shape: (6, 10, 10)
# Episode 4717 started. Initial State Shape: (6, 10, 10)
# Episode 4718 started. Initial State Shape: (6, 10, 10)
# Episode 4719 started. Initial State Shape: (6, 10, 10)
# Episode 4720 started. Initial State Shape: (6, 10, 10)
# Episode 4720: Total Reward: 15, Epsilon: 0.10
# Episode 4721 started. Initial State Shape: (6, 10, 10)
# Episode 4722 started. Initial State Shape: (6, 10, 10)
# Episode 4723 started. Initial State Shape: (6, 10, 10)
# Episode 4724 started. Initial State Shape: (6, 10, 10)
# Episode 4725 started. Initial State Shape: (6, 10, 10)
# Episode 4726 started. Initial State Shape: (6, 10, 10)
# Episode 4727 started. Initial State Shape: (6, 10, 10)
# Episode 4728 started. Initial State Shape: (6, 10, 10)
# Episode 4729 started. Initial State Shape: (6, 10, 10)
# Episode 4730 started. Initial State Shape: (6, 10, 10)
# Episode 4730: Total Reward: 13, Epsilon: 0.10
# Episode 4731 started. Initial State Shape: (6, 10, 10)
# Episode 4732 started. Initial State Shape: (6, 10, 10)
# Episode 4733 started. Initial State Shape: (6, 10, 10)
# Episode 4734 started. Initial State Shape: (6, 10, 10)
# Episode 4735 started. Initial State Shape: (6, 10, 10)
# Episode 4736 started. Initial State Shape: (6, 10, 10)
# Episode 4737 started. Initial State Shape: (6, 10, 10)
# Episode 4738 started. Initial State Shape: (6, 10, 10)
# Episode 4739 started. Initial State Shape: (6, 10, 10)
# Episode 4740 started. Initial State Shape: (6, 10, 10)
# Episode 4740: Total Reward: 8, Epsilon: 0.10
# Episode 4741 started. Initial State Shape: (6, 10, 10)
# Episode 4742 started. Initial State Shape: (6, 10, 10)
# Episode 4743 started. Initial State Shape: (6, 10, 10)
# Episode 4744 started. Initial State Shape: (6, 10, 10)
# Episode 4745 started. Initial State Shape: (6, 10, 10)
# Episode 4746 started. Initial State Shape: (6, 10, 10)
# Episode 4747 started. Initial State Shape: (6, 10, 10)
# Episode 4748 started. Initial State Shape: (6, 10, 10)
# Episode 4749 started. Initial State Shape: (6, 10, 10)
# Episode 4750 started. Initial State Shape: (6, 10, 10)
# Episode 4750: Total Reward: 16, Epsilon: 0.10
# Episode 4751 started. Initial State Shape: (6, 10, 10)
# Episode 4752 started. Initial State Shape: (6, 10, 10)
# Episode 4753 started. Initial State Shape: (6, 10, 10)

# %%
def evaluate_dqn(env, q_network, num_episodes=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    total_rewards = []

    for episode in range(num_episodes):
        state, _ = env.reset()
        state = np.moveaxis(state, -1, 0)  # Fix input shape (C, H, W)
        done = False
        total_reward = 0

        while not done:
            state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            with torch.no_grad():
                action = q_network(state_tensor).argmax(dim=1).item()

            next_state, reward, done, _, _ = env.step(action)
            next_state = np.moveaxis(next_state, -1, 0)  # Fix input shape

            total_reward += reward
            state = next_state

        total_rewards.append(total_reward)
        print(f"Evaluation Episode {episode}: Total Reward: {total_reward}")

    avg_reward = np.mean(total_rewards)
    print(f"Average Reward over {num_episodes} episodes: {avg_reward}")
    return avg_reward

# Run Evaluation
evaluate_dqn(env, trained_model)
# Out:
# Evaluation Episode 0: Total Reward: 1
# Evaluation Episode 1: Total Reward: 23
# Evaluation Episode 2: Total Reward: 47
# Evaluation Episode 3: Total Reward: 19
# Evaluation Episode 4: Total Reward: 27
# Evaluation Episode 5: Total Reward: 23
# Evaluation Episode 6: Total Reward: 19
# Evaluation Episode 7: Total Reward: 23
# Evaluation Episode 8: Total Reward: 23
# Evaluation Episode 9: Total Reward: 8
# Average Reward over 10 episodes: 21.3
# 21.3
